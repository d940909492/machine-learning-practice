# %% [markdown]
# For checking the code for t1, using the sklearn library to check

# %%
from IPython.display import Image
Image("Linear_reg_Error_Equation.png")

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test0.csv')
df
# Out:
#     age  salary
# 0    52   45537
# 1    60   67324
# 2    52    9657
# 3    19   61026
# 4    37   13808
# ..  ...     ...
# 95   41   38384
# 96   48   70075
# 97   53   13415
# 98   61   49453
# 99   56   46459
#
# [100 rows x 2 columns]

# %%
# %matplotlib inline
plt.xlabel('age')
plt.ylabel('salary')
plt.scatter(df.age,df.salary,color='red')

# %%
reg = linear_model.LinearRegression()

reg.fit(df[['age']],df.salary)
# Out:
# LinearRegression()

# %%
n = int(input('Enter the age: '))
reg.predict([[n]])
# Out:
# c:\Users\dong5\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([57042.70804069])
